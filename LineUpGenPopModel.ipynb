# %%
import MLBLineUpFactory as lineup
import numpy as np
Date = 'Sept5'
Know = False
Bat = True
#Prediction = 'Avg'
Prediction = 'TheBAT'
from ModelPopulationEXP import QuickPopulationModel
from ModelPopulationEXP import GPPPopulationModel

# %%
PopLineUp = lineup.MLBLineUpFactory(Date, theBat=True)
PopLineUp.InitalizeOptimizer(Known=Know,Pred='TheBAT')
# Out:
# Academic license - for non-commercial use only

# %%
mean,var,CovVect=QuickPopulationModel(Date, 8,50,200,20,1000, Know)
# Out:
# Optimize a model with 63 rows, 236 columns and 974 nonzeros
# Variable types: 0 continuous, 236 integer (236 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+04]
# Found heuristic solution: objective 79.8800000
# Presolve removed 31 rows and 38 columns
# Presolve time: 0.00s
# Presolved: 32 rows, 198 columns, 583 nonzeros
# Variable types: 0 continuous, 198 integer (198 binary)
#
# Root relaxation: objective 1.150562e+02, 23 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  115.05625    0    2   79.88000  115.05625  44.0%     -    0s
# H    0     0                     114.6100000  115.05625  0.39%     -    0s
# H    0     0                     114.6600000  115.05625  0.35%     -    0s
# ...

# %%
mean
# Out:
# 110.89145944128866

# %%
var
# Out:
# 425.7428152325988

# %%
#Make the popvect
mean1,var1,CovVect1=QuickPopulationModel(Date, 6,(5/28)*100,237,20,1000, Know)
# Out:
# Optimize a model with 63 rows, 236 columns and 974 nonzeros
# Variable types: 0 continuous, 236 integer (236 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+04]
# Found heuristic solution: objective 79.8800000
# Presolve removed 31 rows and 38 columns
# Presolve time: 0.00s
# Presolved: 32 rows, 198 columns, 583 nonzeros
# Variable types: 0 continuous, 198 integer (198 binary)
#
# Root relaxation: objective 1.150562e+02, 23 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  115.05625    0    2   79.88000  115.05625  44.0%     -    0s
# H    0     0                     114.6100000  115.05625  0.39%     -    0s
# H    0     0                     114.6600000  115.05625  0.35%     -    0s
# ...

# %%
mean1
# Out:
# 127.3495939190443

# %%
var1
# Out:
# 408.674360006035

# %%
mean2,var2,CovVect2=GPPPopulationModel(Date, 5,2.5,237,50,2000, Know)
# Out:
# Optimize a model with 63 rows, 236 columns and 974 nonzeros
# Variable types: 0 continuous, 236 integer (236 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+04]
# Found heuristic solution: objective 79.8800000
# Presolve removed 31 rows and 38 columns
# Presolve time: 0.00s
# Presolved: 32 rows, 198 columns, 583 nonzeros
# Variable types: 0 continuous, 198 integer (198 binary)
#
# Root relaxation: objective 1.150562e+02, 23 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  115.05625    0    2   79.88000  115.05625  44.0%     -    0s
# H    0     0                     114.6100000  115.05625  0.39%     -    0s
# H    0     0                     114.6600000  115.05625  0.35%     -    0s
# ...

# %%
mean2

# %%
var2

# %%
PopLineUp.ReturnLineUps(0,2,-0.05,0.05, 500,7,[mean,var,CovVect])
# Out:
# Optimize a model with 63 rows, 236 columns and 974 nonzeros
# Model has 1095 quadratic objective terms
# Variable types: 0 continuous, 236 integer (236 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [4e+00, 3e+01]
#   QObjective range [1e-02, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+04]
# Found heuristic solution: objective -83.5412245
# Presolve removed 31 rows and 30 columns
# Presolve time: 0.00s
# Presolved: 642 rows, 813 columns, 2431 nonzeros
# Variable types: 0 continuous, 813 integer (813 binary)
#
# Root relaxation: objective -4.234727e+01, 84 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -42.34727    0    4  -83.54122  -42.34727  49.3%     -    0s
# H    0     0                     -43.1466477  -42.34727  1.85%     -    0s
# ...

# %%
PopLineUp.ReturnLineUps(0,2,-0.05,0.05, 500,7,[mean1,var1,CovVect1])

# %%
PopLineUp.ReturnLineUps(0,2,-0.05,0.05, 500,7,[mean2,var2,CovVect2])
