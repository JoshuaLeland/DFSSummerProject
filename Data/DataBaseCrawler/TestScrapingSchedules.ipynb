# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %%
Link = 'https://www.fangraphs.com/teams/astros/schedule/?season=2017'

# %%
soup = BeautifulSoup(requests.get(Link).text, "html.parser")

# %%
tags1 = soup.find_all("div","team-schedule-table")[0]

# %%
tags2=tags1.find_all("tr")

# %%
Game1=tags2[1].find_all("td")
Game1
# Out:
# [<td><a href="//www.fangraphs.com/wins.aspx?date=2017-04-03&amp;team=Astros&amp;dh=0&amp;season=2017"><span class="date-full">Apr 3, 2017</span><span class="date-short">4/3</span></a></td>,
#  <td class="alignR">vs</td>,
#  <td class="alignL"><a href="/teams/mariners">SEA</a></td>,
#  <td class="large">59.8%</td>,
#  <td>W</td>,
#  <td>3</td>,
#  <td>0</td>,
#  <td class="alignL hi"><a href="//www.fangraphs.com/statss.aspx?playerid=9434">Dallas Keuchel</a></td>,
#  <td class="alignL hi"><a href="//www.fangraphs.com/statss.aspx?playerid=4772">Felix Hernandez</a></td>]

# %%
Data = []
for i in range(1, len(tags2)):
    Row=[]
    Game1 = tags2[i].find_all("td")
    #Date Home/Away Opp WinP W/L TeamRuns OppSuns TeamStart OppStart
    Date = Game1[0].find("span", "date-full").get_text()
    if(Game1[1].get_text()=='vs'):
        Home = 'Home'
    else:
        Home = 'Away'
    Opp = Game1[2].get_text()
    WinP = float(Game1[3].get_text().strip('%'))
    Win = Game1[4].get_text()
    TeamRuns = float(Game1[5].get_text())
    OppRuns = float(Game1[6].get_text())
    TeamStarterID = Game1[7].find_all('a')[0].get('href').split('=')[1]
    TeamStarterName = Game1[7].find_all('a')[0].get_text()
    OppStarterID = Game1[8].find_all('a')[0].get('href').split('=')[1]
    OppStarterName = Game1[8].find_all('a')[0].get_text()
    Row = [Date, Home, Opp, WinP, Win, TeamRuns, OppRuns, TeamStarterID, TeamStarterName, OppStarterID, OppStarterName]
    Data.append(Row)
TeamSchedule = pd.DataFrame(columns=['Date', 'Home/Away', 'Opp', 'Win Prob', 'Win/Loss', 'TeamRuns', 'Opp Runs', 'StarterID', 'StarterName', 'OppStarterID', 'OppStarterName'], data=Data)

# %%
TeamSchedule
# Out:
#              Date Home/Away  Opp  Win Prob Win/Loss  TeamRuns  Opp Runs  \
# 0     Apr 3, 2017      Home  SEA      59.8        W       3.0       0.0
# 1     Apr 4, 2017      Home  SEA      62.9        W       2.0       1.0
# 2     Apr 5, 2017      Home  SEA      54.9        W       5.0       3.0
# 3     Apr 6, 2017      Home  SEA      59.3        L       2.0       4.0
# 4     Apr 7, 2017      Home  KCR      62.8        L       1.0       5.0
# 5     Apr 8, 2017      Home  KCR      63.9        L       3.0       7.0
# 6     Apr 9, 2017      Home  KCR      66.4        W       5.0       4.0
# 7    Apr 10, 2017      Away  SEA      46.9        L       0.0       6.0
# 8    Apr 11, 2017      Away  SEA      52.5        W       7.0       5.0
# 9    Apr 12, 2017      Away  SEA      53.7        W      10.0       5.0
# 10   Apr 14, 2017      Away  OAK      57.0        W       7.0       2.0
# 11   Apr 15, 2017      Away  OAK      53.9        W      10.0       6.0
# 12   Apr 17, 2017      Home  LAA      58.9        W       3.0       0.0
# 13   Apr 18, 2017      Home  LAA      58.4        L       2.0       5.0
# 14   Apr 19, 2017      Home  LAA      64.2        W       5.0       1.0
# 15   Apr 20, 2017      Home  LAA      60.5        W       2.0       1.0
# 16   Apr 21, 2017      Away  TBR      50.2        W       6.0       3.0
# 17   Apr 22, 2017      Away  TBR      49.5        L       3.0       6.0
# 18   Apr 23, 2017      Away  TBR      49.4        W       6.0       4.0
# 19   Apr 25, 2017      Away  CLE      52.5        W       4.0       2.0
# 20   Apr 26, 2017      Away  CLE      49.3        L       6.0       7.0
# 21   Apr 27, 2017      Away  CLE      35.8        L       3.0       4.0
# 22   Apr 28, 2017      Home  OAK      60.4        W       9.0       4.0
# 23   Apr 29, 2017      Home  OAK      58.6        L       1.0       2.0
# 24   Apr 30, 2017      Home  OAK      66.8        W       7.0       2.0
# 25    May 1, 2017      Home  TEX      68.3        W       6.0       2.0
# 26    May 2, 2017      Home  TEX      54.6        W       8.0       7.0
# 27    May 3, 2017      Home  TEX      64.6        W      10.0       1.0
# 28    May 4, 2017      Home  TEX      62.9        L       4.0      10.0
# 29    May 5, 2017      Away  LAA      55.7        W       7.0       6.0
# ..            ...       ...  ...       ...      ...       ...       ...
# 150  Sep 20, 2017      Home  CHW      75.3        W       4.0       3.0
# 151  Sep 21, 2017      Home  CHW      83.9        L       1.0       3.0
# 152  Sep 22, 2017      Home  LAA      56.8        W       3.0       0.0
# 153  Sep 23, 2017      Home  LAA      57.5        W       6.0       2.0
# 154  Sep 24, 2017      Home  LAA      62.6        L       5.0       7.0
# 155  Sep 25, 2017      Away  TEX      57.5        W      11.0       2.0
# 156  Sep 26, 2017      Away  TEX      55.8        W      14.0       3.0
# 157  Sep 27, 2017      Away  TEX      64.1        W      12.0       2.0
# 158  Sep 28, 2017      Away  BOS      49.2        W      12.0       2.0
# 159  Sep 29, 2017      Away  BOS      54.1        W       3.0       2.0
# 160  Sep 30, 2017      Away  BOS      55.4        L       3.0       6.0
# 161   Oct 1, 2017      Away  BOS      46.5        W       4.0       3.0
# 162   Oct 5, 2017      Home  BOS      50.4        W       8.0       2.0
# 163   Oct 6, 2017      Home  BOS      60.5        W       8.0       2.0
# 164   Oct 8, 2017      Away  BOS      50.2        L       3.0      10.0
# 165   Oct 9, 2017      Away  BOS      51.8        W       5.0       4.0
# 166  Oct 13, 2017      Home  NYY      57.2        W       2.0       1.0
# 167  Oct 14, 2017      Home  NYY      54.8        W       2.0       1.0
# 168  Oct 16, 2017      Away  NYY      53.8        L       1.0       8.0
# 169  Oct 17, 2017      Away  NYY      47.2        L       4.0       6.0
# 170  Oct 18, 2017      Away  NYY      48.9        L       0.0       5.0
# 171  Oct 20, 2017      Home  NYY      54.3        W       7.0       1.0
# 172  Oct 21, 2017      Home  NYY      61.0        W       4.0       0.0
# 173  Oct 24, 2017      Away  LAD      38.6        L       1.0       3.0
# 174  Oct 25, 2017      Away  LAD      45.4        W       7.0       6.0
# 175  Oct 27, 2017      Home  LAD      58.3        W       5.0       3.0
# 176  Oct 28, 2017      Home  LAD      50.8        L       2.0       6.0
# 177  Oct 29, 2017      Home  LAD      47.8        W      13.0      12.0
# 178  Oct 31, 2017      Away  LAD      45.4        L       1.0       3.0
# 179   Nov 1, 2017      Away  LAD      50.2        W       5.0       1.0
#
#     StarterID          StarterName OppStarterID     OppStarterName
# 0        9434       Dallas Keuchel         4772    Felix Hernandez
