# %%
import pandas as pd

# %%
#INIT SECTION -- 
DKSalaries = 'DKSalaries/DKSalariesJuly10.csv'
RawFile = pd.read_csv(DKSalaries)

# %%
def Abv2Name(x):
    return {
        'ARI': 'Diamondbacks',
        'ATL': 'Braves',
        'BAL': 'Orioles',
        'CHC': 'Cubs',
        'CLE': 'Indians',
        'COL': 'Rockies',
        'DET': 'Tigers',
        'MIA': 'Marlins',
        'HOU': 'Astros',
        'LAA': 'Angels',
        'LAD': 'Dodgers',
        'MIL': 'Brewers',
        'MIN': 'Twins',
        'NYM': 'Mets',
        'NYY': 'Yankees',
        'OAK': 'Athletics',
        'PHI': 'Phillies',
        'PIT': 'Pirates',
        'SD': 'Padres',
        'SF': 'Giants',
        'SEA': 'Mariners',
        'STL': 'Cardinals',
        'TEX': 'Rangers',
        'TB': 'Rays',
        'TOR': 'Blue Jays',
        'WAS': 'Nationals',
        'BOS': 'Red Sox',
        'CIN': 'Reds',
        'CWS': 'White Sox',
        'KC': 'Royals',
        'CHW': 'White Sox',
        'KCR' : 'Royals',
        'SDP' : 'Padres',
        'SFG' : 'Giants',
        'TBR' : 'Rays'
    }[x]

# %%
RawFile['Team'] = RawFile.apply(lambda x: Abv2Name(x['TeamAbbrev']), axis=1)

# %%
RawFile
# Out:
#      Position                         Name + ID                   Name  \
# 0          SP           Max Scherzer (10919781)           Max Scherzer
# 1          SP             Chris Sale (10919782)             Chris Sale
# 2          SP           Trevor Bauer (10918873)           Trevor Bauer
# 3          SP       Justin Verlander (10918874)       Justin Verlander
# 4          SP             Aaron Nola (10919783)             Aaron Nola
# 5          SP            Gerrit Cole (10919784)            Gerrit Cole
# 6          SP          Luis Severino (10919786)          Luis Severino
# 7          SP           Jacob deGrom (10919785)           Jacob deGrom
# 8          SP        Clayton Kershaw (10919787)        Clayton Kershaw
# 9          SP            Blake Snell (10919788)            Blake Snell
# 10         SP           James Paxton (10919789)           James Paxton
# 11         SP         Charlie Morton (10919790)         Charlie Morton
# 12         SP      Stephen Strasburg (10919791)      Stephen Strasburg
# 13         SP    Lance McCullers Jr. (10919792)    Lance McCullers Jr.
# 14         SP           Corey Kluber (10919793)           Corey Kluber
# 15         SP           Jose Berrios (10919794)           Jose Berrios
# 16         SP      Madison Bumgarner (10919795)      Madison Bumgarner
# 17         SP         Mike Clevinger (10919796)         Mike Clevinger
# 18         SP        Carlos Carrasco (10919797)        Carlos Carrasco
# 19         SP       Mike Foltynewicz (10919799)       Mike Foltynewicz
# 20         SP       Noah Syndergaard (10919798)       Noah Syndergaard
# 21         SP         Patrick Corbin (10918875)         Patrick Corbin
# 22         SP           Tyler Skaggs (10919800)           Tyler Skaggs
# 23         SP             Zach Eflin (10919801)             Zach Eflin
# 24         SP          Rick Porcello (10919802)          Rick Porcello
# 25         SP           Zack Greinke (10919803)           Zack Greinke
# 26         SP         Freddy Peralta (10919804)         Freddy Peralta
# 27         SP            Kenta Maeda (10919805)            Kenta Maeda
# 28         RP         Ross Stripling (10919806)         Ross Stripling
# 1521  10919769              SS    2000   LAD@SD 07/10/2018 10:10PM ET
# 1522  10919771              SS    2000   KC@MIN 07/10/2018 08:10PM ET
# 1523  10919775              OF    2000   KC@MIN 07/10/2018 08:10PM ET
# 1524  10919778              SS    2000   KC@MIN 07/10/2018 08:10PM ET
# 1525  10919780               C    2000   KC@MIN 07/10/2018 08:10PM ET
#
#      TeamAbbrev  AvgPointsPerGame          Team
# 0           WAS             26.27     Nationals
# 1           BOS             27.77       Red Sox
# 2           CLE             25.98       Indians
# 3           HOU             26.56        Astros
# 4           PHI             23.18      Phillies
# 5           HOU             26.87        Astros
# 6           NYY             25.96       Yankees
# 7           NYM             24.78          Mets
# 8           LAD             17.24       Dodgers
# 9            TB             23.53          Rays
# 10          SEA             23.72      Mariners
# 11          HOU             23.47        Astros
# 12          WAS             21.41     Nationals
# 13          HOU             20.15        Astros
# 14          CLE             23.34       Indians
# 15          MIN             20.62         Twins
# 16           SF             16.55        Giants
# 17          CLE             18.94       Indians
# 18          CLE             18.82       Indians
# 19          ATL             20.94        Braves
# 20          NYM             20.14          Mets
# 21          ARI             23.08  Diamondbacks
# 22          LAA             19.25        Angels
# 23          PHI             18.58      Phillies
# 24          BOS             18.56       Red Sox
# 25          ARI             18.92  Diamondbacks
# 26          MIL             24.96       Brewers
# 27          LAD             16.34       Dodgers
# 28          LAD             12.33       Dodgers
# 29          STL             16.82     Cardinals
# ...         ...               ...           ...
# 1496        SEA              0.00      Mariners
# 1497        SEA              0.00      Mariners
# 1498        PHI              0.00      Phillies
# 1499        NYM              0.00          Mets
# 1500        PIT              0.00       Pirates
# 1501        WAS              0.00     Nationals
# 1502        WAS              0.00     Nationals
# 1503        MIA              0.00       Marlins
# 1504        TOR              0.00     Blue Jays
# 1505        DET              0.00        Tigers
# 1506         SF              0.00        Giants
# 1507        SEA              0.00      Mariners
# 1508        MIN              0.00         Twins
# 1509         KC              0.00        Royals
# 1510         KC              0.00        Royals
# 1511        TEX              0.00       Rangers
# 1512        TEX              0.00       Rangers
# 1513        CWS              0.00     White Sox
# 1514        STL              0.00     Cardinals
# 1515        CLE              0.00       Indians
# 1516        ARI              0.00  Diamondbacks
# 1517         SF              0.00        Giants
# 1518        SEA              0.00      Mariners
# 1519        SEA              2.87      Mariners
# 1520         SD              0.00        Padres
# 1521         SD              0.00        Padres
# 1522        MIN              0.00         Twins
# 1523        MIN              0.00         Twins
# 1524        MIN              0.00         Twins
# 1525        MIN              3.00         Twins
#
# [1526 rows x 10 columns]

# %%
FormattedSalaries = pd.DataFrame()
FormattedSalaries['Name'] = RawFile['Name']
FormattedSalaries['Team'] = RawFile['Team']
FormattedSalaries['Position'] = RawFile['Position']
FormattedSalaries['Salary'] = RawFile['Salary']

# %%
FormattedSalaries
# Out:
#                        Name          Team Position  Salary
# 0              Max Scherzer     Nationals       SP   14300
# 1                Chris Sale       Red Sox       SP   14000
# 2              Trevor Bauer       Indians       SP   13600
# 3          Justin Verlander        Astros       SP   13300
# 4                Aaron Nola      Phillies       SP   13100
# 5               Gerrit Cole        Astros       SP   13000
# 6             Luis Severino       Yankees       SP   13000
# 7              Jacob deGrom          Mets       SP   13000
# 8           Clayton Kershaw       Dodgers       SP   12900
# 9               Blake Snell          Rays       SP   12700
# 10             James Paxton      Mariners       SP   12500
# 11           Charlie Morton        Astros       SP   12200
# 12        Stephen Strasburg     Nationals       SP   12200
# 13      Lance McCullers Jr.        Astros       SP   11900
# 14             Corey Kluber       Indians       SP   11800
# 15             Jose Berrios         Twins       SP   11800
# 16        Madison Bumgarner        Giants       SP   11100
# 17           Mike Clevinger       Indians       SP   10800
# 18          Carlos Carrasco       Indians       SP   10800
# 19         Mike Foltynewicz        Braves       SP   10500
# 20         Noah Syndergaard          Mets       SP   10500
# 21           Patrick Corbin  Diamondbacks       SP   10400
# 22             Tyler Skaggs        Angels       SP   10400
# 23               Zach Eflin      Phillies       SP   10400
# 24            Rick Porcello       Red Sox       SP   10200
# 25             Zack Greinke  Diamondbacks       SP   10200
# 26           Freddy Peralta       Brewers       SP   10200
# 27              Kenta Maeda       Dodgers       SP   10100
# 28           Ross Stripling       Dodgers       RP   10000
# 29            Miles Mikolas     Cardinals       SP    9900
# ...                     ...           ...      ...     ...
# 1496       Kirk Nieuwenhuis      Mariners       OF    2200
# 1497        Tuffy Gosewisch      Mariners        C    2200
# 1498          Mickey Moniak      Phillies       OF    2200
# 1499         Andres Gimenez          Mets       SS    2200
# 1500            Daniel Nava       Pirates       OF    2200
# 1501            Ryan Raburn     Nationals       OF    2200
# 1502         Carter Kieboom     Nationals       SS    2200
# 1503        Scott Van Slyke       Marlins    1B/OF    2200
# 1504          Logan Warmoth     Blue Jays       SS    2100
# 1505  Jarrod Saltalamacchia        Tigers        C    2100
# 1506          Andres Blanco        Giants    2B/SS    2100
# 1507        Cameron Perkins      Mariners       OF    2100
# 1508           Chris Heisey         Twins       OF    2100
# 1509            Nick Pratto        Royals       1B    2100
# 1510             Khalil Lee        Royals       OF    2100
# 1511          Leody Taveras       Rangers       OF    2000
# 1512         Bubba Thompson       Rangers       OF    2000
# 1513       Blake Rutherford     White Sox       OF    2000
# 1514           Delvin Perez     Cardinals       SS    2000
# 1515            Mike Napoli       Indians       1B    2000
# 1516       Daniel Robertson  Diamondbacks       OF    2000
# 1517           Heliot Ramos        Giants       OF    2000
# 1518              Joe Rizzo      Mariners       3B    2000
# 1519          Ichiro Suzuki      Mariners       OF    2000
# 1520           Luis Torrens        Padres        C    2000
# 1521          Allen Cordoba        Padres       SS    2000
# 1522          Wander Javier         Twins       SS    2000
# 1523         Alex Kirilloff         Twins       OF    2000
# 1524            Royce Lewis         Twins       SS    2000
# 1525          Juan Graterol         Twins        C    2000
#
# [1526 rows x 4 columns]

# %%
#Attach Fangraphs predictions
BatterPred = 'FanGraphPred/July10/FanGraphsBatterJuly10.csv'
PitcherPred = 'FanGraphPred/July10/FanGraphsPitcherJuly10.csv'

# %%
#Load the prediction files.
BatterPredDF = pd.read_csv(BatterPred)
PitcherPredDF = pd.read_csv(PitcherPred)

# %%
#Drop useless columns
BatterPredDF.drop(columns=['Game','Pos','PA','H','1B','2B','3B','HR','R','RBI','SB','CS','BB','SO','Yahoo','FanDuel', 'playerid'], inplace=True)
PitcherPredDF.drop(columns=['Game','W','IP','TBF','H','1B','2B','3B','HR','BB','SO','Yahoo','FanDuel', 'playerid'], inplace=True)

# %%
FanGraphPred = pd.concat([BatterPredDF,PitcherPredDF]).rename(columns={'DraftKings':'DKFG'})

# %%
FanGraphPred.head()
# Out:
#                Name          Team   DKFG
# 0    Ryan Yarbrough          Rays  15.98
# 1     Eddie Rosario         Twins  12.24
# 2     J.D. Martinez       Red Sox  12.01
# 3      Mookie Betts       Red Sox  11.92
# 4  Paul Goldschmidt  Diamondbacks  11.27

# %%
#Merge the salaries with original.
FormattedSalaries = FormattedSalaries.merge(FanGraphPred, how='left', left_on=['Name', 'Team'], right_on=['Name', 'Team']).dropna(subset=['DKFG'])

# %%
FormattedSalaries.head()
# Out:
#                 Name          Team Position  Salary   DKFG
# 2       Trevor Bauer       Indians       SP   13600  19.93
# 3   Justin Verlander        Astros       SP   13300  28.44
# 21    Patrick Corbin  Diamondbacks       SP   10400  15.17
# 29     Miles Mikolas     Cardinals       SP    9900  16.24
# 38       Sean Manaea     Athletics       SP    9200  12.43

# %%
#Input the RotoGrinders Data.
BatterPred = 'RotoGPred/July10/mlb-hitterJuly10.csv'
PitcherPred = 'RotoGPred/July10/mlb-pitcherJuly10.csv'

# %%
BatterPredDF = pd.read_csv(BatterPred, header=None)
PitcherPredDF = pd.read_csv(PitcherPred, header=None)

# %%
BatterPredDF.head()
# Out:
#                  0     1    2   3    4   5      6     7
# 0     Mitch Garver  3400  MIN   C  KCR NaN  0.999  5.90
# 1     Brian Dozier  4100  MIN  2B  KCR NaN  0.751  8.82
# 2  Alcides Escobar  2600  KCR  SS  MIN NaN  0.999  5.21
# 3   Mike Moustakas  4400  KCR  3B  MIN NaN  0.999  8.90
# 4       Lucas Duda  3600  KCR  1B  MIN NaN  0.999  7.52

# %%
BatterPredDF['Team'] = BatterPredDF.apply(lambda x: Abv2Name(x[2]), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-90273bc7cc4c> in <module>()
# ----> 1 BatterPredDF['Team'] = BatterPredDF.apply(lambda x: Abv2Name(x[2]), axis=1)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4971             try:
#    4972                 for i, v in enumerate(series_gen):
# -> 4973                     results[i] = func(v)
#    4974                     keys.append(v.name)
#    4975             except Exception as e:
#
# <ipython-input-55-90273bc7cc4c> in <lambda>(x)
# ----> 1 BatterPredDF['Team'] = BatterPredDF.apply(lambda x: Abv2Name(x[2]), axis=1)
#
# <ipython-input-54-f942aeaf3a6d> in Abv2Name(x)
#      35         'SDP' : 'Padres',
#      36         'SFG' : 'Giants'
# ---> 37     }[x]
#
# KeyError: ('TBR', 'occurred at index 217')
