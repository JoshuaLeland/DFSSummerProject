# %%
import pandas as pd
import numpy as np
import os

# %%
def convertMonth(x):
       return {
        '08': 'Aug',
        '07': 'July',
        '06': 'June'
    }.get(x,None)

# %%
#Get Active Batter List
ActiveBatterList = pd.read_csv("./DataBaseCrawler/MLBBatterRoster2018.csv",index_col=0)
ActivePitcherList = pd.read_csv("./DataBaseCrawler/MLBBatterRoster2018.csv",index_col=0)

# %%
ActiveBatterList.head()
# Out:
#                 Name     Team     ID  \
# 0      J.D. Martinez  Red Sox   6184
# 1  Andrew Benintendi  Red Sox  17901
# 2         Brock Holt  Red Sox   9345
# 3      Eduardo Nunez  Red Sox   6848
# 4        Ian Kinsler  Red Sox   6195
#
#                                                 Link    G   AB   PA    H  1B  \
# 0  statsd.aspx?playerid=6184&position=OF&type=1&g...  122  466  529  155  82
# 1  statsd.aspx?playerid=17901&position=OF&type=1&...  121  468  539  139  83
# 2  statsd.aspx?playerid=9345&position=2B/OF&type=...   85  264  300   70  51
# 3  statsd.aspx?playerid=6848&position=3B/SS&type=...  107  408  426  105  75
# 4  statsd.aspx?playerid=6195&position=2B&type=1&g...    9   28   31    7   6
#
#    2B  ...    BB  IBB   SO  HBP  SF  SH  GDP  SB  CS    AVG
# 0  34  ...    55    7  123    4   4   0   15   5   1  0.333
# 1  35  ...    63    1   87    2   6   0    6  20   2  0.297
# 2  15  ...    29    2   52    5   2   0    6   6   6  0.265
# ...

# %%
ID = 6184
GameLog = pd.read_csv("./DataBaseCrawler/GameLogs/Batters/"+str(ID)+"GL.csv",index_col=0)

# %%
FPHistory = GameLog[['Date', 'Team', 'Opp', 'DKfp']]
x = ['2018' in x for x in FPHistory['Date'].values]
Results2018=FPHistory[x]

# %%
#Convert Dates
# Out:
#            Date Team   Opp  DKfp
# 1    2018-08-23  BOS   CLE  11.0
# 2    2018-08-21  BOS   CLE   5.0
# 3    2018-08-19  BOS   TBR   0.0
# 4    2018-08-17  BOS   TBR  11.0
# 5    2018-08-14  BOS  @PHI   3.0
# 6    2018-08-11  BOS  @BAL  34.0
# 7    2018-08-10  BOS  @BAL  18.0
# 8    2018-08-08  BOS  @TOR  17.0
# 9    2018-08-05  BOS   NYY   9.0
# 10   2018-08-03  BOS   NYY   7.0
# 11   2018-08-02  BOS   NYY  26.0
# 12   2018-07-30  BOS   PHI   2.0
# 13   2018-07-28  BOS   MIN  21.0
# 14   2018-07-26  BOS   MIN   3.0
# 15   2018-07-23  BOS  @BAL  10.0
# 16   2018-07-20  BOS  @DET   2.0
# 17   2018-07-14  BOS   TOR  18.0
# 18   2018-07-12  BOS   TOR   3.0
# 19   2018-07-10  BOS   TEX   7.0
# 20   2018-07-07  BOS  @KCR  14.0
# 21   2018-07-06  BOS  @KCR  21.0
# 22   2018-07-03  BOS  @WSN  25.0
# 23   2018-06-30  BOS  @NYY  17.0
# 24   2018-06-28  BOS   LAA   4.0
# 25   2018-06-26  BOS   LAA  19.0
# 26   2018-06-23  BOS   SEA   8.0
# 27   2018-06-21  BOS  @MIN  14.0
# ...
