# %%
from gurobipy import *
import pandas as pd
import numpy as np

# %%
#Import the Player File
Projections = pd.read_csv('DKProjectionsJuly12.csv')

# %%
Projections.drop(columns='Unnamed: 0', inplace=True)

# %%
Players = Projections.as_matrix()
n, d = Players.shape
n
# Out:
# 124

# %%
#Split the Players.
SplitPlayers = []
for i in range(n):
    Pos = Players[i,2].split('/')
    if len(Pos) > 1:
        Copy = Players[i].copy()
        Players[i,2] = Pos[0]
        Copy[2] = Pos[1]
        Copy[0] = Copy[0] + ' ' + Pos[1]
        SplitPlayers.append(Copy)

# %%
Players
# Out:
# array([['Max Scherzer', 'Nationals', 'SP', 13300, 31.44, 30.18,
#         141.13838021905013],
#        ['James Paxton', 'Mariners', 'SP', 12500, 15.96, 19.77,
#         137.02249884379688],
#        ['Blake Snell', 'Rays', 'SP', 11700, 15.48, 17.28,
#         117.78698507414148],
#        ['Luis Severino', 'Yankees', 'SP', 10800, 18.73, 20.79,
#         141.7986483887356],
#        ['Corey Kluber', 'Indians', 'SP', 10200, 23.49, 23.39,
#         160.2558300566215],
#        ['Ross Stripling', 'Dodgers', 'RP', 9100, 21.41, 21.85,
#         74.50591066481994],
#        ['Tyler Skaggs', 'Angels', 'SP', 7700, 15.68, 16.89,
#         97.77655892287477],
#        ['J.A. Happ', 'Blue Jays', 'SP', 7400, 13.06, 16.33,
#         105.3359263558502],
#        ['David Price', 'Red Sox', 'SP', 7100, 15.82, 19.71,
#         129.46061280639557],
#        ['Kyle Gibson', 'Twins', 'SP', 6700, 12.63, 14.33,
#         108.91064554102259],
#        ['Mookie Betts', 'Red Sox', 'OF', 6200, 10.91, 9.97,
#         98.48591311921871],
#        ['Mike Trout', 'Angels', 'OF', 6000, 9.77, 9.66,
#         111.22359666594332],
#        ['J.D. Martinez', 'Red Sox', 'OF', 5900, 10.63, 9.2,
#         69.33428461336321],
#        ['Steven Matz', 'Mets', 'SP', 5900, 16.25, 14.71,
#         106.5906681034483],
#        ['Jameson Taillon', 'Pirates', 'SP', 5700, 15.97, 17.59,
#         96.43178547433484],
#        ['Andrew Benintendi', 'Red Sox', 'OF', 5300, 8.91, 7.69,
#         75.40879108996539],
#        ['Xander Bogaerts', 'Red Sox', 'SS', 5200, 8.2, 7.39,
#         58.11045805082552],
#        ['Tyson Ross', 'Padres', 'SP', 5100, 13.12, 15.44,
#         126.87139594344423],
#        ['Francisco Lindor', 'Indians', 'SS', 5000, 8.02, 7.52,
#         81.4299926089586],
#        ['Bryce Harper', 'Nationals', 'OF', 5000, 7.95, 7.74,
#         80.3703871517163],
#        ['Aaron Judge', 'Yankees', 'OF', 4900, 8.24, 7.52,
#         102.18408169563324],
#        ['Max Muncy', 'Dodgers', '1B', 4900, 10.35, 8.9,
#         31.03105122511197],
#        ['Wil Myers', 'Padres', 'OF', 4900, 8.12, 7.95, 65.62979206832172],
#        ['Jose Ramirez', 'Indians', '3B', 4800, 8.22, 7.5,
#         66.77551596271634],
#        ['Trea Turner', 'Nationals', 'SS', 4800, 9.11, 9.74,
#         92.34741225461036],
#        ['Juan Soto', 'Nationals', 'OF', 4800, 7.4, 6.54,
#         76.96074380165291],
#        ['Jesus Aguilar', 'Brewers', '1B', 4800, 8.48, 6.94,
#         29.91691389794949],
#        ['Starling Marte', 'Pirates', 'OF', 4800, 9.45, 10.04,
#         71.9906050873972],
#        ['Christian Yelich', 'Brewers', 'OF', 4800, 8.33, 8.73,
#         67.84980032640263],
#        ['Justin Smoak', 'Blue Jays', '1B', 4700, 7.76, 7.74,
#         36.7596043091752],
#        ['Matt Kemp', 'Dodgers', 'OF', 4700, 8.88, 7.7, 70.17410839237544],
#        ['Anthony Rendon', 'Nationals', '3B', 4700, 8.51, 9.07,
#         64.29663923182443],
#        ['Wade Miley', 'Brewers', 'SP', 4700, 12.79, 11.86,
#         116.03510754153999],
#        ['Eric Thames', 'Brewers', '1B', 4700, 8.78, 9.11,
#         51.76881566235962],
#        ['Cody Bellinger', 'Dodgers', '1B', 4600, 10.13, 9.02,
#         80.5914256198347],
#        ['Lorenzo Cain', 'Brewers', 'OF', 4600, 8.58, 7.33,
#         60.23557383799861],
#        ['Teoscar Hernandez', 'Blue Jays', 'OF', 4500, 8.44, 8.7,
#         51.137932819212246],
#        ['Steve Pearce', 'Red Sox', '1B', 4500, 8.25, 7.83,
#         34.35919241917133],
#        ['Aaron Hicks', 'Yankees', 'OF', 4500, 7.11, 6.38,
#         40.456358536559016],
#        ['Brett Gardner', 'Yankees', 'OF', 4500, 7.06, 6.53,
#         55.537706975720006],
#        ['Nelson Cruz', 'Mariners', 'OF', 4500, 9.11, 9.12,
#         71.82590731206956],
#        ['Giancarlo Stanton', 'Yankees', 'OF', 4400, 8.3, 7.52,
#         81.48767212213187],
#        ['Didi Gregorius', 'Yankees', 'SS', 4400, 7.45, 6.46,
#         44.3329384600721],
#        ['Mitch Haniger', 'Mariners', 'OF', 4400, 8.55, 8.72,
#         64.22037286423702],
#        ['Mark Reynolds', 'Nationals', '1B', 4400, 7.61, 7.84,
#         52.28900905139837],
#        ['Travis Shaw', 'Brewers', '3B', 4400, 8.06, 6.45,
#         56.783294670862816],
#        ['Justin Upton', 'Angels', 'OF', 4300, 7.81, 6.43,
#         69.19454636622115],
#        ['Joc Pederson', 'Dodgers', 'OF', 4300, 9.76, 8.28,
#         38.465310287380255],
#        ['Chris Taylor', 'Dodgers', 'OF', 4300, 7.65, 6.62,
#         43.62849953076597],
#        ['Michael Brantley', 'Indians', 'OF', 4200, 8.0, 7.28,
#         61.475151640083475],
#        ['Andrelton Simmons', 'Angels', 'SS', 4200, 7.34, 6.74,
#         40.09640088436724],
#        ['Yasmani Grandal', 'Dodgers', 'C', 4200, 8.28, 6.41,
#         41.73943067033977],
#        ['Justin Turner', 'Dodgers', '3B', 4200, 9.39, 6.93,
#         39.684259888647325],
#        ['Eddie Rosario', 'Twins', 'OF', 4200, 8.53, 7.18,
#         57.77348193961682],
#        ['Wilson Ramos', 'Rays', 'C', 4200, 8.76, 6.77, 43.90438992948181],
#        ['C.J. Cron', 'Rays', '1B', 4200, 8.2, 7.19, 43.317888379841726],
#        ['Kevin Pillar', 'Blue Jays', 'OF', 4100, 6.85, 6.36,
#         39.04284838416203],
#        ['Jean Segura', 'Mariners', 'SS', 4100, 8.7, 7.97,
#         59.95657171619201],
#        ['Albert Pujols', 'Angels', '1B', 4100, 6.99, 5.9,
#         92.98417541721977],
#        ['Randal Grichuk', 'Blue Jays', 'OF', 4000, 8.89, 7.3,
#         42.151359159800684],
#        ['Edwin Encarnacion', 'Indians', '1B', 4000, 6.82, 6.62,
#         68.59893017360896],
#        ['Miguel Andujar', 'Yankees', '3B', 4000, 6.81, 5.23,
#         55.05273586343545],
#        ['Daniel Murphy', 'Nationals', '2B', 4000, 7.13, 6.52,
#         55.06105674586317],
#        ['Brian Dozier', 'Twins', '2B', 4000, 8.78, 8.72, 70.116047377527],
#        ['Daniel Robertson', 'Rays', '2B', 4000, 8.03, 6.24,
#         32.03245563271605],
#        ['Corey Dickerson', 'Pirates', 'OF', 4000, 8.23, 6.63,
#         51.24600373927618],
#        ['Eric Hosmer', 'Padres', '1B', 3900, 8.22, 6.66,
#         58.27001960061325],
#        ['Kevin Kiermaier', 'Rays', 'OF', 3900, 8.91, 7.82,
#         45.17153985589905],
#        ['Kendrys Morales', 'Blue Jays', '1B', 3800, 7.16, 7.07,
#         50.46799905897496],
#        ['Eduardo Nunez', 'Red Sox', '2B', 3800, 7.61, 6.49,
#         43.14582791363164],
#        ['Brock Holt', 'Red Sox', '2B', 3700, 6.41, 6.1,
#         33.579343262796094],
#        ['Ryon Healy', 'Mariners', '1B', 3700, 7.56, 7.54,
#         51.98654409652399],
#        ['Kyle Seager', 'Mariners', '3B', 3700, 6.98, 6.47,
#         56.87097045703222],
#        ['Asdrubal Cabrera', 'Mets', '2B', 3700, 6.52, 6.39,
#         52.07404255437949],
#        ['Devon Travis', 'Blue Jays', '2B', 3600, 6.56, 4.93,
#         50.48476454293629],
#        ['Aledmys Diaz', 'Blue Jays', 'SS', 3600, 6.31, 5.48,
#         47.25209250418503],
#        ['Yonder Alonso', 'Indians', '1B', 3600, 6.74, 6.72,
#         35.392415972421716],
#        ['Jason Kipnis', 'Indians', '2B', 3600, 6.01, 5.29,
#         62.53524478538578],
#        ['Dee Gordon', 'Mariners', '2B', 3600, 7.27, 7.17,
#         65.42195311702889],
#        ['Ian Kinsler', 'Angels', '2B', 3600, 6.57, 6.07,
#         74.71521715749684],
#        ['David Fletcher', 'Angels', '2B', 3600, 6.8, 6.48,
#         18.367346938775512],
#        ['Brandon Nimmo', 'Mets', 'OF', 3600, 6.23, 6.19,
#         36.88173841686657],
#        ['Mallex Smith', 'Rays', 'OF', 3600, 7.34, 6.89,
#         33.98641919420552],
#        ['Brad Miller', 'Brewers', '1B', 3600, 7.14, 5.85,
#         39.147005113221326],
#        ['Josh Harrison', 'Pirates', '2B', 3600, 7.03, 6.84,
#         37.7632553833719],
#        ['Elias Diaz', 'Pirates', 'C', 3600, 7.59, 7.04,
#         23.901234567901238],
#        ['Sandy Leon', 'Red Sox', 'C', 3500, 6.51, 5.65,
#         25.97710718002081],
#        ['Denard Span', 'Mariners', 'OF', 3500, 6.22, 5.32,
#         60.475186431181314],
#        ['Jefry Marte', 'Angels', '1B', 3500, 6.0, 4.41,
#         25.04833251651147],
#        ['Travis Jankowski', 'Padres', 'OF', 3500, 6.93, 6.56,
#         26.168727480516186],
#        ['Jorge Polanco', 'Twins', 'SS', 3500, 7.32, 5.53,
#         47.34449962124401],
#        ['Josh Bell', 'Pirates', '1B', 3500, 7.68, 6.59,
#         45.48190427378304],
#        ['Martin Maldonado', 'Angels', 'C', 3400, 5.1, 5.48,
#         20.977051962361163],
#        ['Manuel Margot', 'Padres', 'OF', 3400, 6.29, 4.53,
#         43.71027155724265],
#        ['Tyler Saladino', 'Brewers', 'SS', 3400, 6.4, 5.58,
#         27.81967606987393],
#        ['Russell Martin', 'Blue Jays', 'C', 3300, 6.62, 5.77,
#         48.787438117695],
#        ['Austin Romine', 'Yankees', 'C', 3300, 5.33, 4.45,
#         15.749023498046995],
#        ['Kole Calhoun', 'Angels', 'OF', 3300, 4.77, 6.12,
#         48.53195415765225],
#        ['Carlos Asuaje', 'Padres', '2B', 3300, 6.5, 5.73,
#         22.012807280915748],
#        ['Austin Hedges', 'Padres', 'C', 3300, 5.54, 5.23,
#         20.982310093652448],
#        ['Max Kepler', 'Twins', 'OF', 3300, 5.97, 5.43, 45.25268364381028],
#        ['Neil Walker', 'Yankees', '1B', 3200, 5.34, 4.66,
#         50.0476936998532],
#        ['Jose Pirela', 'Padres', '2B', 3200, 6.82, 5.41,
#         35.173628680122185],
#        ['Matt Wieters', 'Nationals', 'C', 3200, 5.81, 4.87,
#         40.78338146678981],
#        ['Joe Mauer', 'Twins', '1B', 3200, 6.78, 6.47, 60.95166661927856],
#        ['Jordy Mercer', 'Pirates', 'SS', 3200, 6.59, 5.76,
#         30.5171689530404],
#        ['David Freese', 'Pirates', '1B', 3200, 7.66, 6.53,
#         38.45648799748199],
#        ['Yan Gomes', 'Indians', 'C', 3100, 5.38, 4.97, 37.83371973741024],
#        ['Greg Allen', 'Indians', 'OF', 3100, 4.89, 4.68,
#         15.49609473418997],
#        ['Freddy Galvis', 'Padres', 'SS', 3100, 6.04, 5.35,
#         33.46323010787815],
#        ['Adeiny Hechavarria', 'Rays', 'SS', 3100, 6.36, 5.09,
#         27.323139431041174],
#        ['Jordan Luplow', 'Pirates', 'OF', 3100, 8.55, 6.09,
#         21.670630202140302],
#        ['Michael Conforto', 'Mets', 'OF', 3000, 6.32, 5.86,
#         47.65325768459672],
#        ['Kevin Plawecki', 'Mets', 'C', 3000, 4.44, 4.59,
#         20.393871661385237],
#        ['Willians Astudillo', 'Twins', '3B', 3000, 7.87, 6.48, 31.36],
#        ['Robbie Grossman', 'Twins', 'OF', 3000, 7.09, 7.15, 38.59515625],
#        ['Tyler Naquin', 'Indians', 'OF', 2900, 5.75, 4.56,
#         28.832230623818532],
#        ['Wilmer Flores', 'Mets', '1B', 2900, 6.37, 4.76,
#         32.78769028640213],
#        ['Jose Reyes', 'Mets', '3B', 2900, 4.84, 5.65, 78.8105158940716],
#        ['Ehire Adrianza', 'Twins', 'SS', 2800, 6.41, 6.81,
#         15.47657455632716],
#        ['Erik Kratz', 'Brewers', 'C', 2800, 6.53, 4.98,
#         17.158453962588407],
#        ['Guillermo Heredia', 'Mariners', 'OF', 2700, 5.46, 6.02,
#         17.819470572426766],
#        ['David Freitas', 'Mariners', 'C', 2700, 5.25, 5.43,
#         11.472424557752342],
#        ['Bobby Wilson', 'Twins', 'C', 2700, 5.22, 3.3,
#         11.193100016852718]], dtype=object)

# %%
SplitPlayers = np.array(SplitPlayers)

# %%
SplitPlayers
# Out:
# array([['Max Muncy 3B', 'Dodgers', '3B', 4900, 10.35, 8.9,
#         31.03105122511197],
#        ['Eric Thames OF', 'Brewers', 'OF', 4700, 8.78, 9.11,
#         51.76881566235962],
#        ['Cody Bellinger OF', 'Dodgers', 'OF', 4600, 10.13, 9.02,
#         80.5914256198347],
#        ['Steve Pearce OF', 'Red Sox', 'OF', 4500, 8.25, 7.83,
#         34.35919241917133],
#        ['Chris Taylor SS', 'Dodgers', 'SS', 4300, 7.65, 6.62,
#         43.62849953076597],
#        ['Daniel Robertson SS', 'Rays', 'SS', 4000, 8.03, 6.24,
#         32.03245563271605],
#        ['Eduardo Nunez SS', 'Red Sox', 'SS', 3800, 7.61, 6.49,
#         43.14582791363164],
#        ['Brock Holt SS', 'Red Sox', 'SS', 3700, 6.41, 6.1,
#         33.579343262796094],
#        ['Dee Gordon OF', 'Mariners', 'OF', 3600, 7.27, 7.17,
#         65.42195311702889],
#        ['David Fletcher 3B', 'Angels', '3B', 3600, 6.8, 6.48,
#         18.367346938775512],
#        ['Brad Miller 2B', 'Brewers', '2B', 3600, 7.14, 5.85,
#         39.147005113221326],
#        ['Jefry Marte 3B', 'Angels', '3B', 3500, 6.0, 4.41,
#         25.04833251651147],
#        ['Neil Walker 2B', 'Yankees', '2B', 3200, 5.34, 4.66,
#         50.0476936998532],
#        ['Jose Pirela OF', 'Padres', 'OF', 3200, 6.82, 5.41,
#         35.173628680122185],
#        ['David Freese 3B', 'Pirates', '3B', 3200, 7.66, 6.53,
#         38.45648799748199],
#        ['Willians Astudillo C', 'Twins', 'C', 3000, 7.87, 6.48, 31.36],
#        ['Wilmer Flores 3B', 'Mets', '3B', 2900, 6.37, 4.76,
#         32.78769028640213],
#        ['Jose Reyes SS', 'Mets', 'SS', 2900, 4.84, 5.65,
#         78.8105158940716]], dtype=object)

# %%
TotalPlayers = np.concatenate([Players,SplitPlayers])
TotalPlayers
# Out:
# array([['Max Scherzer', 'Nationals', 'SP', 13300, 31.44, 30.18,
#         141.13838021905013],
#        ['James Paxton', 'Mariners', 'SP', 12500, 15.96, 19.77,
#         137.02249884379688],
#        ['Blake Snell', 'Rays', 'SP', 11700, 15.48, 17.28,
#         117.78698507414148],
#        ['Luis Severino', 'Yankees', 'SP', 10800, 18.73, 20.79,
#         141.7986483887356],
#        ['Corey Kluber', 'Indians', 'SP', 10200, 23.49, 23.39,
#         160.2558300566215],
#        ['Ross Stripling', 'Dodgers', 'RP', 9100, 21.41, 21.85,
#         74.50591066481994],
#        ['Tyler Skaggs', 'Angels', 'SP', 7700, 15.68, 16.89,
#         97.77655892287477],
#        ['J.A. Happ', 'Blue Jays', 'SP', 7400, 13.06, 16.33,
#         105.3359263558502],
#        ['David Price', 'Red Sox', 'SP', 7100, 15.82, 19.71,
#         129.46061280639557],
#        ['Kyle Gibson', 'Twins', 'SP', 6700, 12.63, 14.33,
#         108.91064554102259],
#        ['Mookie Betts', 'Red Sox', 'OF', 6200, 10.91, 9.97,
#         98.48591311921871],
#        ['Mike Trout', 'Angels', 'OF', 6000, 9.77, 9.66,
#         111.22359666594332],
#        ['J.D. Martinez', 'Red Sox', 'OF', 5900, 10.63, 9.2,
#         69.33428461336321],
#        ['Steven Matz', 'Mets', 'SP', 5900, 16.25, 14.71,
#         106.5906681034483],
#        ['Jameson Taillon', 'Pirates', 'SP', 5700, 15.97, 17.59,
#         96.43178547433484],
#        ['Andrew Benintendi', 'Red Sox', 'OF', 5300, 8.91, 7.69,
#         75.40879108996539],
#        ['Xander Bogaerts', 'Red Sox', 'SS', 5200, 8.2, 7.39,
#         58.11045805082552],
#        ['Tyson Ross', 'Padres', 'SP', 5100, 13.12, 15.44,
#         126.87139594344423],
#        ['Francisco Lindor', 'Indians', 'SS', 5000, 8.02, 7.52,
#         81.4299926089586],
#        ['Bryce Harper', 'Nationals', 'OF', 5000, 7.95, 7.74,
#         80.3703871517163],
#        ['Aaron Judge', 'Yankees', 'OF', 4900, 8.24, 7.52,
#         102.18408169563324],
#        ['Max Muncy', 'Dodgers', '1B', 4900, 10.35, 8.9,
#         31.03105122511197],
#        ['Wil Myers', 'Padres', 'OF', 4900, 8.12, 7.95, 65.62979206832172],
#        ['Jose Ramirez', 'Indians', '3B', 4800, 8.22, 7.5,
#         66.77551596271634],
#        ['Trea Turner', 'Nationals', 'SS', 4800, 9.11, 9.74,
#         92.34741225461036],
#        ['Juan Soto', 'Nationals', 'OF', 4800, 7.4, 6.54,
#         76.96074380165291],
#        ['Jesus Aguilar', 'Brewers', '1B', 4800, 8.48, 6.94,
#         29.91691389794949],
#        ['Starling Marte', 'Pirates', 'OF', 4800, 9.45, 10.04,
#         71.9906050873972],
#        ['Christian Yelich', 'Brewers', 'OF', 4800, 8.33, 8.73,
#         67.84980032640263],
#        ['Justin Smoak', 'Blue Jays', '1B', 4700, 7.76, 7.74,
#         36.7596043091752],
#        ['Matt Kemp', 'Dodgers', 'OF', 4700, 8.88, 7.7, 70.17410839237544],
#        ['Anthony Rendon', 'Nationals', '3B', 4700, 8.51, 9.07,
#         64.29663923182443],
#        ['Wade Miley', 'Brewers', 'SP', 4700, 12.79, 11.86,
#         116.03510754153999],
#        ['Eric Thames', 'Brewers', '1B', 4700, 8.78, 9.11,
#         51.76881566235962],
#        ['Cody Bellinger', 'Dodgers', '1B', 4600, 10.13, 9.02,
#         80.5914256198347],
#        ['Lorenzo Cain', 'Brewers', 'OF', 4600, 8.58, 7.33,
#         60.23557383799861],
#        ['Teoscar Hernandez', 'Blue Jays', 'OF', 4500, 8.44, 8.7,
#         51.137932819212246],
#        ['Steve Pearce', 'Red Sox', '1B', 4500, 8.25, 7.83,
#         34.35919241917133],
#        ['Aaron Hicks', 'Yankees', 'OF', 4500, 7.11, 6.38,
#         40.456358536559016],
#        ['Brett Gardner', 'Yankees', 'OF', 4500, 7.06, 6.53,
#         55.537706975720006],
#        ['Nelson Cruz', 'Mariners', 'OF', 4500, 9.11, 9.12,
#         71.82590731206956],
#        ['Giancarlo Stanton', 'Yankees', 'OF', 4400, 8.3, 7.52,
#         81.48767212213187],
#        ['Didi Gregorius', 'Yankees', 'SS', 4400, 7.45, 6.46,
#         44.3329384600721],
#        ['Mitch Haniger', 'Mariners', 'OF', 4400, 8.55, 8.72,
#         64.22037286423702],
#        ['Mark Reynolds', 'Nationals', '1B', 4400, 7.61, 7.84,
#         52.28900905139837],
#        ['Travis Shaw', 'Brewers', '3B', 4400, 8.06, 6.45,
#         56.783294670862816],
#        ['Justin Upton', 'Angels', 'OF', 4300, 7.81, 6.43,
#         69.19454636622115],
#        ['Joc Pederson', 'Dodgers', 'OF', 4300, 9.76, 8.28,
#         38.465310287380255],
#        ['Chris Taylor', 'Dodgers', 'OF', 4300, 7.65, 6.62,
#         43.62849953076597],
#        ['Michael Brantley', 'Indians', 'OF', 4200, 8.0, 7.28,
#         61.475151640083475],
#        ['Andrelton Simmons', 'Angels', 'SS', 4200, 7.34, 6.74,
#         40.09640088436724],
#        ['Yasmani Grandal', 'Dodgers', 'C', 4200, 8.28, 6.41,
#         41.73943067033977],
#        ['Justin Turner', 'Dodgers', '3B', 4200, 9.39, 6.93,
#         39.684259888647325],
#        ['Eddie Rosario', 'Twins', 'OF', 4200, 8.53, 7.18,
#         57.77348193961682],
#        ['Wilson Ramos', 'Rays', 'C', 4200, 8.76, 6.77, 43.90438992948181],
#        ['C.J. Cron', 'Rays', '1B', 4200, 8.2, 7.19, 43.317888379841726],
#        ['Kevin Pillar', 'Blue Jays', 'OF', 4100, 6.85, 6.36,
#         39.04284838416203],
#        ['Jean Segura', 'Mariners', 'SS', 4100, 8.7, 7.97,
#         59.95657171619201],
#        ['Albert Pujols', 'Angels', '1B', 4100, 6.99, 5.9,
#         92.98417541721977],
#        ['Randal Grichuk', 'Blue Jays', 'OF', 4000, 8.89, 7.3,
#         42.151359159800684],
#        ['Edwin Encarnacion', 'Indians', '1B', 4000, 6.82, 6.62,
#         68.59893017360896],
#        ['Miguel Andujar', 'Yankees', '3B', 4000, 6.81, 5.23,
#         55.05273586343545],
#        ['Daniel Murphy', 'Nationals', '2B', 4000, 7.13, 6.52,
#         55.06105674586317],
#        ['Brian Dozier', 'Twins', '2B', 4000, 8.78, 8.72, 70.116047377527],
#        ['Daniel Robertson', 'Rays', '2B', 4000, 8.03, 6.24,
#         32.03245563271605],
#        ['Corey Dickerson', 'Pirates', 'OF', 4000, 8.23, 6.63,
#         51.24600373927618],
#        ['Eric Hosmer', 'Padres', '1B', 3900, 8.22, 6.66,
#         58.27001960061325],
#        ['Kevin Kiermaier', 'Rays', 'OF', 3900, 8.91, 7.82,
#         45.17153985589905],
#        ['Kendrys Morales', 'Blue Jays', '1B', 3800, 7.16, 7.07,
#         50.46799905897496],
#        ['Eduardo Nunez', 'Red Sox', '2B', 3800, 7.61, 6.49,
#         43.14582791363164],
#        ['Brock Holt', 'Red Sox', '2B', 3700, 6.41, 6.1,
#         33.579343262796094],
#        ['Ryon Healy', 'Mariners', '1B', 3700, 7.56, 7.54,
#         51.98654409652399],
#        ['Kyle Seager', 'Mariners', '3B', 3700, 6.98, 6.47,
#         56.87097045703222],
#        ['Asdrubal Cabrera', 'Mets', '2B', 3700, 6.52, 6.39,
#         52.07404255437949],
#        ['Devon Travis', 'Blue Jays', '2B', 3600, 6.56, 4.93,
#         50.48476454293629],
#        ['Aledmys Diaz', 'Blue Jays', 'SS', 3600, 6.31, 5.48,
#         47.25209250418503],
#        ['Yonder Alonso', 'Indians', '1B', 3600, 6.74, 6.72,
#         35.392415972421716],
#        ['Jason Kipnis', 'Indians', '2B', 3600, 6.01, 5.29,
#         62.53524478538578],
#        ['Dee Gordon', 'Mariners', '2B', 3600, 7.27, 7.17,
#         65.42195311702889],
#        ['Ian Kinsler', 'Angels', '2B', 3600, 6.57, 6.07,
#         74.71521715749684],
#        ['David Fletcher', 'Angels', '2B', 3600, 6.8, 6.48,
#         18.367346938775512],
#        ['Brandon Nimmo', 'Mets', 'OF', 3600, 6.23, 6.19,
#         36.88173841686657],
#        ['Mallex Smith', 'Rays', 'OF', 3600, 7.34, 6.89,
#         33.98641919420552],
#        ['Brad Miller', 'Brewers', '1B', 3600, 7.14, 5.85,
#         39.147005113221326],
#        ['Josh Harrison', 'Pirates', '2B', 3600, 7.03, 6.84,
#         37.7632553833719],
#        ['Elias Diaz', 'Pirates', 'C', 3600, 7.59, 7.04,
#         23.901234567901238],
#        ['Sandy Leon', 'Red Sox', 'C', 3500, 6.51, 5.65,
#         25.97710718002081],
#        ['Denard Span', 'Mariners', 'OF', 3500, 6.22, 5.32,
#         60.475186431181314],
#        ['Jefry Marte', 'Angels', '1B', 3500, 6.0, 4.41,
#         25.04833251651147],
#        ['Travis Jankowski', 'Padres', 'OF', 3500, 6.93, 6.56,
#         26.168727480516186],
#        ['Jorge Polanco', 'Twins', 'SS', 3500, 7.32, 5.53,
#         47.34449962124401],
#        ['Josh Bell', 'Pirates', '1B', 3500, 7.68, 6.59,
#         45.48190427378304],
#        ['Martin Maldonado', 'Angels', 'C', 3400, 5.1, 5.48,
#         20.977051962361163],
#        ['Manuel Margot', 'Padres', 'OF', 3400, 6.29, 4.53,
#         43.71027155724265],
#        ['Tyler Saladino', 'Brewers', 'SS', 3400, 6.4, 5.58,
#         27.81967606987393],
#        ['Russell Martin', 'Blue Jays', 'C', 3300, 6.62, 5.77,
#         48.787438117695],
#        ['Austin Romine', 'Yankees', 'C', 3300, 5.33, 4.45,
#         15.749023498046995],
#        ['Kole Calhoun', 'Angels', 'OF', 3300, 4.77, 6.12,
#         48.53195415765225],
#        ['Carlos Asuaje', 'Padres', '2B', 3300, 6.5, 5.73,
#         22.012807280915748],
#        ['Austin Hedges', 'Padres', 'C', 3300, 5.54, 5.23,
#         20.982310093652448],
#        ['Max Kepler', 'Twins', 'OF', 3300, 5.97, 5.43, 45.25268364381028],
#        ['Neil Walker', 'Yankees', '1B', 3200, 5.34, 4.66,
#         50.0476936998532],
#        ['Jose Pirela', 'Padres', '2B', 3200, 6.82, 5.41,
#         35.173628680122185],
#        ['Matt Wieters', 'Nationals', 'C', 3200, 5.81, 4.87,
#         40.78338146678981],
#        ['Joe Mauer', 'Twins', '1B', 3200, 6.78, 6.47, 60.95166661927856],
#        ['Jordy Mercer', 'Pirates', 'SS', 3200, 6.59, 5.76,
#         30.5171689530404],
#        ['David Freese', 'Pirates', '1B', 3200, 7.66, 6.53,
#         38.45648799748199],
#        ['Yan Gomes', 'Indians', 'C', 3100, 5.38, 4.97, 37.83371973741024],
#        ['Greg Allen', 'Indians', 'OF', 3100, 4.89, 4.68,
#         15.49609473418997],
#        ['Freddy Galvis', 'Padres', 'SS', 3100, 6.04, 5.35,
#         33.46323010787815],
#        ['Adeiny Hechavarria', 'Rays', 'SS', 3100, 6.36, 5.09,
#         27.323139431041174],
#        ['Jordan Luplow', 'Pirates', 'OF', 3100, 8.55, 6.09,
#         21.670630202140302],
#        ['Michael Conforto', 'Mets', 'OF', 3000, 6.32, 5.86,
#         47.65325768459672],
#        ['Kevin Plawecki', 'Mets', 'C', 3000, 4.44, 4.59,
#         20.393871661385237],
#        ['Willians Astudillo', 'Twins', '3B', 3000, 7.87, 6.48, 31.36],
#        ['Robbie Grossman', 'Twins', 'OF', 3000, 7.09, 7.15, 38.59515625],
#        ['Tyler Naquin', 'Indians', 'OF', 2900, 5.75, 4.56,
#         28.832230623818532],
#        ['Wilmer Flores', 'Mets', '1B', 2900, 6.37, 4.76,
#         32.78769028640213],
#        ['Jose Reyes', 'Mets', '3B', 2900, 4.84, 5.65, 78.8105158940716],
#        ['Ehire Adrianza', 'Twins', 'SS', 2800, 6.41, 6.81,
#         15.47657455632716],
#        ['Erik Kratz', 'Brewers', 'C', 2800, 6.53, 4.98,
#         17.158453962588407],
#        ['Guillermo Heredia', 'Mariners', 'OF', 2700, 5.46, 6.02,
#         17.819470572426766],
#        ['David Freitas', 'Mariners', 'C', 2700, 5.25, 5.43,
#         11.472424557752342],
#        ['Bobby Wilson', 'Twins', 'C', 2700, 5.22, 3.3,
#         11.193100016852718],
#        ['Max Muncy 3B', 'Dodgers', '3B', 4900, 10.35, 8.9,
#         31.03105122511197],
#        ['Eric Thames OF', 'Brewers', 'OF', 4700, 8.78, 9.11,
#         51.76881566235962],
#        ['Cody Bellinger OF', 'Dodgers', 'OF', 4600, 10.13, 9.02,
#         80.5914256198347],
#        ['Steve Pearce OF', 'Red Sox', 'OF', 4500, 8.25, 7.83,
#         34.35919241917133],
#        ['Chris Taylor SS', 'Dodgers', 'SS', 4300, 7.65, 6.62,
#         43.62849953076597],
#        ['Daniel Robertson SS', 'Rays', 'SS', 4000, 8.03, 6.24,
#         32.03245563271605],
#        ['Eduardo Nunez SS', 'Red Sox', 'SS', 3800, 7.61, 6.49,
#         43.14582791363164],
#        ['Brock Holt SS', 'Red Sox', 'SS', 3700, 6.41, 6.1,
#         33.579343262796094],
#        ['Dee Gordon OF', 'Mariners', 'OF', 3600, 7.27, 7.17,
#         65.42195311702889],
#        ['David Fletcher 3B', 'Angels', '3B', 3600, 6.8, 6.48,
#         18.367346938775512],
#        ['Brad Miller 2B', 'Brewers', '2B', 3600, 7.14, 5.85,
#         39.147005113221326],
#        ['Jefry Marte 3B', 'Angels', '3B', 3500, 6.0, 4.41,
#         25.04833251651147],
#        ['Neil Walker 2B', 'Yankees', '2B', 3200, 5.34, 4.66,
#         50.0476936998532],
#        ['Jose Pirela OF', 'Padres', 'OF', 3200, 6.82, 5.41,
#         35.173628680122185],
#        ['David Freese 3B', 'Pirates', '3B', 3200, 7.66, 6.53,
#         38.45648799748199],
#        ['Willians Astudillo C', 'Twins', 'C', 3000, 7.87, 6.48, 31.36],
#        ['Wilmer Flores 3B', 'Mets', '3B', 2900, 6.37, 4.76,
#         32.78769028640213],
#        ['Jose Reyes SS', 'Mets', 'SS', 2900, 4.84, 5.65,
#         78.8105158940716]], dtype=object)

# %%
#Create the model
m = Model('Binary Quadratic Model')
# Out:
# Academic license - for non-commercial use only

# %%
#Assign the Varplayers and copys -- Returns Dictonary
varPlayers = m.addVars(TotalPlayers[:,0], vtype=GRB.BINARY)

# %%
#Put in position constraints.
for name in SplitPlayers[:,0]:
    sNames = name.split(' ')
    #print(name)
    
    #Get the matching platers.
    player1 = varPlayers[name]
    player2 = varPlayers[sNames[0]+' '+sNames[1]]
    
    #Add Constraint
    m.addConstr(player1 + player2 <=1,sNames[0]+' '+sNames[1] +' Postion C' )
m.update()

# %%
Salaries = np.array([x[3]*varPlayers[x[0]] for x in TotalPlayers])
m.addConstr(np.sum(Salaries)<=50000, 'Salary C')
m.update()

# %%
# Out:
# <gurobi.LinExpr: 13300.0 C0 + 12500.0 C1 + 11700.0 C2 + 10800.0 C3 + 10200.0 C4 + 9100.0 C5 + 7700.0 C6 + 7400.0 C7 + 7100.0 C8 + 6700.0 C9 + 6200.0 C10 + 6000.0 C11 + 5900.0 C12 + 5900.0 C13 + 5700.0 C14 + 5300.0 C15 + 5200.0 C16 + 5100.0 C17 + 5000.0 C18 + 5000.0 C19 + 4900.0 C20 + 4900.0 C21 + 4900.0 C22 + 4800.0 C23 + 4800.0 C24 + 4800.0 C25 + 4800.0 C26 + 4800.0 C27 + 4800.0 C28 + 4700.0 C29 + 4700.0 C30 + 4700.0 C31 + 4700.0 C32 + 4700.0 C33 + 4600.0 C34 + 4600.0 C35 + 4500.0 C36 + 4500.0 C37 + 4500.0 C38 + 4500.0 C39 + 4500.0 C40 + 4400.0 C41 + 4400.0 C42 + 4400.0 C43 + 4400.0 C44 + 4400.0 C45 + 4300.0 C46 + 4300.0 C47 + 4300.0 C48 + 4200.0 C49 + 4200.0 C50 + 4200.0 C51 + 4200.0 C52 + 4200.0 C53 + 4200.0 C54 + 4200.0 C55 + 4100.0 C56 + 4100.0 C57 + 4100.0 C58 + 4000.0 C59 + 4000.0 C60 + 4000.0 C61 + 4000.0 C62 + 4000.0 C63 + 4000.0 C64 + 4000.0 C65 + 3900.0 C66 + 3900.0 C67 + 3800.0 C68 + 3800.0 C69 + 3700.0 C70 + 3700.0 C71 + 3700.0 C72 + 3700.0 C73 + 3600.0 C74 + 3600.0 C75 + 3600.0 C76 + 3600.0 C77 + 3600.0 C78 + 3600.0 C79 + 3600.0 C80 + 3600.0 C81 + 3600.0 C82 + 3600.0 C83 + 3600.0 C84 + 3600.0 C85 + 3500.0 C86 + 3500.0 C87 + 3500.0 C88 + 3500.0 C89 + 3500.0 C90 + 3500.0 C91 + 3400.0 C92 + 3400.0 C93 + 3400.0 C94 + 3300.0 C95 + 3300.0 C96 + 3300.0 C97 + 3300.0 C98 + 3300.0 C99 + 3300.0 C100 + 3200.0 C101 + 3200.0 C102 + 3200.0 C103 + 3200.0 C104 + 3200.0 C105 + 3200.0 C106 + 3100.0 C107 + 3100.0 C108 + 3100.0 C109 + 3100.0 C110 + 3100.0 C111 + 3000.0 C112 + 3000.0 C113 + 3000.0 C114 + 3000.0 C115 + 2900.0 C116 + 2900.0 C117 + 2900.0 C118 + 2800.0 C119 + 2800.0 C120 + 2700.0 C121 + 2700.0 C122 + 2700.0 C123 + 4900.0 C124 + 4700.0 C125 + 4600.0 C126 + 4500.0 C127 + 4300.0 C128 + 4000.0 C129 + 3800.0 C130 + 3700.0 C131 + 3600.0 C132 + 3600.0 C133 + 3600.0 C134 + 3500.0 C135 + 3200.0 C136 + 3200.0 C137 + 3200.0 C138 + 3000.0 C139 + 2900.0 C140 + 2900.0 C141>

# %%
OFList = np.array([varPlayers[x[0]] for x in TotalPlayers if x[2]=='OF'])
SSList = np.array([varPlayers[x[0]] for x in TotalPlayers if x[2]=='SS'])
TBList = np.array([varPlayers[x[0]] for x in TotalPlayers if x[2]=='3B'])
SBList = np.array([varPlayers[x[0]] for x in TotalPlayers if x[2]=='2B'])
FBList = np.array([varPlayers[x[0]] for x in TotalPlayers if x[2]=='1B'])
CList = np.array([varPlayers[x[0]] for x in TotalPlayers if x[2]=='C'])
SPList = np.array([varPlayers[x[0]] for x in TotalPlayers if x[2]=='SP'])

# %%
m.addConstr(np.sum(OFList) ==3, 'OF Constraint')
m.addConstr(np.sum(SSList) ==1, 'SS Constraint')
m.addConstr(np.sum(TBList) ==1, '3B Constraint')
m.addConstr(np.sum(SBList) ==1, '2B Constraint')
m.addConstr(np.sum(FBList) ==1, '1B Constraint')
m.addConstr(np.sum(CList) ==1, 'C Constraint')
m.addConstr(np.sum(SPList) ==2, 'SP Constraint')
m.update()

# %%
#Add Team Constraints
# Out:
# <gurobi.Constr SP Constraint>
